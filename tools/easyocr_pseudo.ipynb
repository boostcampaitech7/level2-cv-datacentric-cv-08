# %%
import cv2
import json
import os
import easyocr

# %%
def generate_datumaro_json_with_easyocr(image_paths, output_json_path, language="jp"):
    dataset = {
        "info": {},
        "categories": {
            "label": {
                "labels": [
                    {
                        "name": "text",
                        "parent": "",
                        "attributes": []
                    }
                ],
                "attributes": []
            }
        },
        "items": []
    }

    label_name_to_id = {"text": 0}
    
    #언어 선택 부분 
    reader = easyocr.Reader(language, gpu=True)  # GPU 사용 가능 시 gpu=True로 설정

    for image_id, image_path in enumerate(image_paths):
        image = cv2.imread(image_path)
        h, w, _ = image.shape

        image_name = os.path.basename(image_path)
        item_id = os.path.splitext(image_name)[0]

        # EasyOCR로 텍스트 데이터 추출
        results = reader.readtext(image)

        annotations = []
        annotation_counter = 0  # 어노테이션 ID 카운터

        for bbox, text, confidence in results:
            if confidence < 0.5:
                continue  # 신뢰도가 80% 미만이면 무시

            # bbox 좌표 추출 및 변환
            points = [(float(x), float(y)) for x, y in bbox]
            flattened_points = [coord for point in points for coord in point]

            # 어노테이션 정보 추가
            annotation = {
                "id": annotation_counter,
                "type": "polygon",
                "attributes": {
                    "text": text,
                    "confidence": float(confidence),
                    "occluded": False  # 필요에 따라 변경 가능
                },
                "group": 0,
                "label_id": label_name_to_id["text"],
                "points": flattened_points,
                "z_order": 0
            }
            annotations.append(annotation)
            annotation_counter += 1

        # 이미지 정보 추가
        item = {
            "id": item_id,
            "annotations": annotations,
            "image": {
                "size": [int(h), int(w)],
                "path": image_path  # 필요한 경우 경로 수정
            }
        }
        dataset["items"].append(item)

    # JSON 파일로 저장
    with open(output_json_path, 'w', encoding='utf-8') as f:
        json.dump(dataset, f, ensure_ascii=False, indent=4)

    print(f"Datumaro 포맷의 JSON 파일이 생성되었습니다: {output_json_path}")

# %%
image_folder = '/data/ephemeral/home/cleansing'  # 이미지가 저장된 폴더 경로
image_paths = [os.path.join(image_folder, f) for f in os.listdir(image_folder) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]
output_json_path = 'ocr_vi.json'

# %%
generate_datumaro_json_with_easyocr(image_paths, output_json_path, ["vi","en"])
# Out:
# Downloading recognition model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% CompleteDatumaro 포맷의 JSON 파일이 생성되었습니다: cord_zh.json

# %% [markdown]
# # CVAT 포맷 맞추기

# %%
import json

task_name = "cord"
plus_name = "images/" + "train/"

json_path = "/data/ephemeral/home/cord_zh.json"

with open(json_path,'r') as f:
    data = json.load(f)

# %%
data["categories"]['label']['labels'][0]['name'] = 1
data["categories"]['label']['labels'][0]['name']
# Out:
# 1

# %%
for d in data['items']:
    file = d['id']
    d['id'] = plus_name + file
    print(d['id'])
# Out:
# images/train/image_5736
# images/train/image_3242
# images/train/image_683
# images/train/image_719
# images/train/image_1777
# images/train/image_2833
# images/train/image_294
# images/train/image_2411
# images/train/image_95
# images/train/image_2132
# images/train/image_712
# images/train/image_4210
# images/train/image_497
# images/train/image_2180
# images/train/image_1219
# images/train/image_761
# images/train/image_4
# images/train/image_3514
# images/train/image_564
# images/train/image_993
# images/train/image_2026
# images/train/image_4356
# images/train/image_421
# images/train/image_4261
# images/train/image_3141
# images/train/image_4331
# images/train/image_1227
# images/train/image_4896
# images/train/image_5720
# images/train/image_5631
# images/train/image_1384
# images/train/image_1758
# images/train/image_1637
# images/train/image_3690
# images/train/image_159
# images/train/image_3081
# images/train/image_4876
# images/train/image_1381
# images/train/image_3204
# images/train/image_2094
# images/train/image_5233
# images/train/image_1820
# images/train/image_3329
# images/train/image_837
# images/train/image_3925
# images/train/image_3255
# images/train/image_1432
# images/train/image_4808
# images/train/image_3883
# images/train/image_592
# images/train/image_1478
# images/train/image_5430
# images/train/image_4487
# images/train/image_2071
# images/train/image_503
# images/train/image_5003
# images/train/image_1576
# images/train/image_1781
# images/train/image_4732
# images/train/image_3534
# images/train/image_4103
# images/train/image_2938
# images/train/image_1500
# images/train/image_2631
# images/train/image_3931
# images/train/image_2363
# images/train/image_5204
# images/train/image_2564
# images/train/image_3551
# images/train/image_3786
# images/train/image_142
# images/train/image_3370
# images/train/image_3314
# images/train/image_5640
# images/train/image_4762
# images/train/image_1559
# images/train/image_942
# images/train/image_2732
# images/train/image_695
# images/train/image_2197
# images/train/image_4549
# images/train/image_476
# images/train/image_2895
# images/train/image_5679
# images/train/image_4586
# images/train/image_451
# images/train/image_4620
# images/train/image_2166
# images/train/image_1156
# images/train/image_184
# images/train/image_1743
# images/train/image_1987
# images/train/image_3301
# images/train/image_1076
# images/train/image_475
# images/train/image_1667
# images/train/image_3848
# images/train/image_3777
# images/train/image_1143
# images/train/image_1891
# images/train/image_4965
# images/train/image_1057
# images/train/image_2952
# images/train/image_5600
# images/train/image_2383
# images/train/image_5257
# images/train/image_2057
# images/train/image_4027
# images/train/image_5484
# images/train/image_4593
# images/train/image_1453
# images/train/image_2624
# images/train/image_408
# images/train/image_3530
# images/train/image_78
# images/train/image_1339
# images/train/image_3502
# images/train/image_3082
# images/train/image_3322
# images/train/image_697
# images/train/image_4349
# images/train/image_454
# images/train/image_10
# images/train/image_5373
# images/train/image_4465
# images/train/image_4856
# images/train/image_1857
# images/train/image_742
# images/train/image_730
# images/train/image_4960
# images/train/image_331
# images/train/image_478
# images/train/image_5229
# images/train/image_4782
# images/train/image_3480
# images/train/image_3659
# images/train/image_3427
# images/train/image_2902
# images/train/image_517
# images/train/image_1603
# images/train/image_5320
# images/train/image_1998
# images/train/image_488
# images/train/image_1250
# images/train/image_2455
# images/train/image_1883
# images/train/image_1099
# images/train/image_3611
# images/train/image_2068
# images/train/image_3247
# images/train/image_2763
# images/train/image_655
# images/train/image_781
# images/train/image_262
# images/train/image_4248
# images/train/image_3829
# images/train/image_615
# images/train/image_2160
# images/train/image_3401
# images/train/image_1813
# images/train/image_4399
# images/train/image_3726
# images/train/image_1343
# images/train/image_3386
# images/train/image_1420
# images/train/image_1170
# images/train/image_3090
# images/train/image_2324
# images/train/image_1063
# images/train/image_345
# images/train/image_2223
# images/train/image_3009
# images/train/image_4333
# images/train/image_1992
# images/train/image_4120
# images/train/image_2725
# images/train/image_1204
# images/train/image_1727
# images/train/image_2009
# images/train/image_3181
# images/train/image_4332
# images/train/image_4307
# images/train/image_4870
# images/train/image_4099
# images/train/image_3167
# images/train/image_752
# images/train/image_1330
# images/train/image_2011
# images/train/image_3868
# images/train/image_3063
# images/train/image_4448
# images/train/image_1684
# images/train/image_3279
# images/train/image_5396
# images/train/image_5284
# images/train/image_4752
# images/train/image_4235
# images/train/image_5272
# images/train/image_1097
# images/train/image_1508

# %%
with open("syzh.json",'w') as f:
    json.dump(data, f, ensure_ascii=False, indent=4)
